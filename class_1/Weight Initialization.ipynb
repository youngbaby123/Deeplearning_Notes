# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
D = np.random.randn(1000,500)
hidden_layer_sizes = [500]*10
nonlinearities = ["relu"]*len(hidden_layer_sizes)

# %%
act = {"relu" : lambda x:np.maximum(0,x), "tanh" : lambda x:np.tanh(x)}
Hs = {}
for i in xrange(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1]
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) * 0.01
    
    H = np.dot(X, W)
    H = act[nonlinearities[i]](H)
    Hs[i] = H

# %%
print "input layer had mean {} and std {}".format(np.mean(D), np.std(D))
layer_means = [np.mean(H) for i,H in Hs.iteritems()]
layer_stds = [np.std(H) for i,H in Hs.iteritems()]
for i,H in Hs.iteritems():
    print "hidden layer {} had mean {} and std {}".format(i+1, layer_means[i], layer_stds[i])

plt.figure(figsize=(30,10))
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, "ob-")
plt.title("layer mean")
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, "or-")
plt.title('layer std')

plt.figure(figsize=(30,10))
for i,H in Hs.iteritems():
#     if i>1:
#         break
    plt.subplot(1,len(Hs),i+1)
    plt.xlim( 0, 1 )
    plt.hist(H.ravel(), 30 , range=(-1,1))
# Out:
# input layer had mean -0.000697300691147 and std 0.999547574349
# hidden layer 1 had mean 0.0891822132069 and std 0.130695233718
# hidden layer 2 had mean 0.015061601886 and std 0.0215324097232
# hidden layer 3 had mean 0.00244052479679 and std 0.00351820149072
# hidden layer 4 had mean 0.000394894386441 and std 0.000571565910319
# hidden layer 5 had mean 5.60264666474e-05 and std 8.56016793336e-05
# hidden layer 6 had mean 9.65177946106e-06 and std 1.43174461855e-05
# hidden layer 7 had mean 1.58953536204e-06 and std 2.38420705097e-06
# hidden layer 8 had mean 2.62482184147e-07 and std 3.75345693159e-07
# hidden layer 9 had mean 4.0556044333e-08 and std 5.87017003718e-08
# hidden layer 10 had mean 6.57657075911e-09 and std 9.57022033762e-09

# %%
D = np.random.randn(1000,500)
hidden_layer_sizes = [500]*10
nonlinearities = ["relu"]*len(hidden_layer_sizes)

print "input layer had mean {} and std {}".format(np.mean(D), np.std(D))
layer_means = [np.mean(H) for i,H in Hs.iteritems()]
layer_stds = [np.std(H) for i,H in Hs.iteritems()]
for i,H in Hs.iteritems():
    print "hidden layer {} had mean {} and std {}".format(i+1, layer_means[i], layer_stds[i])

act = {"relu" : lambda x:np.maximum(0,x), "tanh" : lambda x:np.tanh(x)}
Hs = {}
for i in xrange(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1]
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) * 0.01
    
    H = np.dot(X, W)
    H = act[nonlinearities[i]](H)
    Hs[i] = H   
    
plt.figure(figsize=(30,10))
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, "ob-")
plt.title("layer mean")
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, "or-")
plt.title('layer std')

plt.figure(figsize=(30,10))
for i,H in Hs.iteritems():
#     if i>1:
#         break
    plt.subplot(1,len(Hs),i+1)
    plt.xlim( -1, 1 )
    plt.hist(H.ravel(), 30 , range=(-1,1))
# Out:
# input layer had mean 0.00200796227412 and std 0.999442697821
# hidden layer 1 had mean 0.0891822132069 and std 0.130695233718
# hidden layer 2 had mean 0.015061601886 and std 0.0215324097232
# hidden layer 3 had mean 0.00244052479679 and std 0.00351820149072
# hidden layer 4 had mean 0.000394894386441 and std 0.000571565910319
# hidden layer 5 had mean 5.60264666474e-05 and std 8.56016793336e-05
# hidden layer 6 had mean 9.65177946106e-06 and std 1.43174461855e-05
# hidden layer 7 had mean 1.58953536204e-06 and std 2.38420705097e-06
# hidden layer 8 had mean 2.62482184147e-07 and std 3.75345693159e-07
# hidden layer 9 had mean 4.0556044333e-08 and std 5.87017003718e-08
# hidden layer 10 had mean 6.57657075911e-09 and std 9.57022033762e-09

# %%
D = np.random.randn(1000,500)
hidden_layer_sizes = [500]*10
nonlinearities = ["relu"]*len(hidden_layer_sizes)

act = {"relu" : lambda x:np.maximum(0,x), "tanh" : lambda x:np.tanh(x)}
Hs = {}
for i in xrange(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1]
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) * 1.0
    
    H = np.dot(X, W)
    H = act[nonlinearities[i]](H)
    Hs[i] = H
    
    print "input layer had mean {} and std {}".format(np.mean(D), np.std(D))
layer_means = [np.mean(H) for i,H in Hs.iteritems()]
layer_stds = [np.std(H) for i,H in Hs.iteritems()]
for i,H in Hs.iteritems():
    print "hidden layer {} had mean {} and std {}".format(i+1, layer_means[i], layer_stds[i])

plt.figure(figsize=(30,10))
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, "ob-")
plt.title("layer mean")
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, "or-")
plt.title('layer std')

plt.figure(figsize=(30,10))
for i,H in Hs.iteritems():
#     if i>1:
#         break
    plt.subplot(1,len(Hs),i+1)
    plt.xlim( 0, 0.5 )
    plt.hist(H.ravel(), 30 , range=(-1,1))
# Out:
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# input layer had mean 0.000747077431102 and std 0.999415171279
# hidden layer 1 had mean 8.93392764674 and std 13.0585068672
# hidden layer 2 had mean 135.92460876 and std 203.140693086
# hidden layer 3 had mean 2262.07037354 and std 3286.70958458
# hidden layer 4 had mean 36433.0606828 and std 51649.0062573
# hidden layer 5 had mean 569158.664669 and std 828249.350112
# hidden layer 6 had mean 8942458.4338 and std 13065526.1443
# hidden layer 7 had mean 141877555.055 and std 207339081.767
# hidden layer 8 had mean 2153845817.03 and std 3133880052.02
# hidden layer 9 had mean 35891151791.7 and std 49878981838.6
# hidden layer 10 had mean 5.43546013347e+11 and std 7.89131287253e+11

# %%
D = np.random.randn(1000,500)
hidden_layer_sizes = [500]*10
nonlinearities = ["tanh"]*len(hidden_layer_sizes)

act = {"relu" : lambda x:np.maximum(0,x), "tanh" : lambda x:np.tanh(x)}
Hs = {}
for i in xrange(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1]
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) * 1.0
    
    H = np.dot(X, W)
    H = act[nonlinearities[i]](H)
    Hs[i] = H
    
    print "input layer had mean {} and std {}".format(np.mean(D), np.std(D))
layer_means = [np.mean(H) for i,H in Hs.iteritems()]
layer_stds = [np.std(H) for i,H in Hs.iteritems()]
for i,H in Hs.iteritems():
    print "hidden layer {} had mean {} and std {}".format(i+1, layer_means[i], layer_stds[i])

plt.figure(figsize=(30,10))
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, "ob-")
plt.title("layer mean")
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, "or-")
plt.title('layer std')

plt.figure(figsize=(30,10))
for i,H in Hs.iteritems():
#     if i>1:
#         break
    plt.subplot(1,len(Hs),i+1)
    plt.hist(H.ravel(), 30 , range=(-1,1))
# Out:
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# input layer had mean -0.000523753701167 and std 1.0001707011
# hidden layer 1 had mean 0.000495478935453 and std 0.982036567367
# hidden layer 2 had mean -0.000495153180862 and std 0.981728024149
# hidden layer 3 had mean 0.00224007239529 and std 0.981685332064
# hidden layer 4 had mean -0.00191907581221 and std 0.981764672147
# hidden layer 5 had mean 0.00229384668496 and std 0.981677901981
# hidden layer 6 had mean -0.000397331217292 and std 0.98157610798
# hidden layer 7 had mean -0.00049014101421 and std 0.981975756615
# hidden layer 8 had mean 0.000256530433342 and std 0.981644893996
# hidden layer 9 had mean 0.000284914627264 and std 0.981741827311
# hidden layer 10 had mean 0.000200444419342 and std 0.981597018879

# %%
D = np.random.randn(1000,500)
hidden_layer_sizes = [500]*10
nonlinearities = ["tanh"]*len(hidden_layer_sizes)

act = {"relu" : lambda x:np.maximum(0,x), "tanh" : lambda x:np.tanh(x)}
Hs = {}
for i in xrange(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1]
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) /np.sqrt(fan_in)
    
    H = np.dot(X, W)
    H = act[nonlinearities[i]](H)
    Hs[i] = H
    
    print "input layer had mean {} and std {}".format(np.mean(D), np.std(D))
layer_means = [np.mean(H) for i,H in Hs.iteritems()]
layer_stds = [np.std(H) for i,H in Hs.iteritems()]
for i,H in Hs.iteritems():
    print "hidden layer {} had mean {} and std {}".format(i+1, layer_means[i], layer_stds[i])

plt.figure(figsize=(30,10))
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, "ob-")
plt.title("layer mean")
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, "or-")
plt.title('layer std')

plt.figure(figsize=(30,10))
for i,H in Hs.iteritems():
#     if i>1:
#         break
    plt.subplot(1,len(Hs),i+1)
    plt.xlim( -1, 1 )
    plt.hist(H.ravel(), 30 , range=(-1,1))
# Out:
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# input layer had mean 0.000954261555963 and std 1.00059726799
# hidden layer 1 had mean -0.0014163722431 and std 0.627733069566
# hidden layer 2 had mean -0.000527286155429 and std 0.48571371138
# hidden layer 3 had mean 0.000476181953496 and std 0.407383657324
# hidden layer 4 had mean 7.10580991955e-05 and std 0.355463480009
# hidden layer 5 had mean 4.87320287151e-05 and std 0.319815117754
# hidden layer 6 had mean -0.00031754823929 and std 0.293448128027
# hidden layer 7 had mean -0.0006003004966 and std 0.272571091392
# hidden layer 8 had mean 8.82304022069e-05 and std 0.255960147011
# hidden layer 9 had mean -0.000744763423415 and std 0.24090740349
# hidden layer 10 had mean -6.9197018001e-05 and std 0.228430713031

# %%
D = np.random.randn(1000,500)
hidden_layer_sizes = [500]*10
nonlinearities = ["relu"]*len(hidden_layer_sizes)

act = {"relu" : lambda x:np.maximum(0,x), "tanh" : lambda x:np.tanh(x)}
Hs = {}
for i in xrange(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1]
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) /np.sqrt(fan_in)
    
    H = np.dot(X, W)
    H = act[nonlinearities[i]](H)
    Hs[i] = H
    
    print "input layer had mean {} and std {}".format(np.mean(D), np.std(D))
layer_means = [np.mean(H) for i,H in Hs.iteritems()]
layer_stds = [np.std(H) for i,H in Hs.iteritems()]
for i,H in Hs.iteritems():
    print "hidden layer {} had mean {} and std {}".format(i+1, layer_means[i], layer_stds[i])

plt.figure(figsize=(30,10))
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, "ob-")
plt.title("layer mean")
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, "or-")
plt.title('layer std')

plt.figure(figsize=(30,10))
for i,H in Hs.iteritems():
#     if i>1:
#         break
    plt.subplot(1,len(Hs),i+1)
    plt.xlim( 0, 1 )
    plt.hist(H.ravel(), 30 , range=(-1,1))
# Out:
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# input layer had mean -0.00293197787751 and std 0.998574319715
# hidden layer 1 had mean 0.397679052283 and std 0.58228776086
# hidden layer 2 had mean 0.274948239406 and std 0.407516317584
# hidden layer 3 had mean 0.193190242816 and std 0.281500175724
# hidden layer 4 had mean 0.138112592014 and std 0.199264150506
# hidden layer 5 had mean 0.100842178561 and std 0.145076536465
# hidden layer 6 had mean 0.0751443132128 and std 0.107383844808
# hidden layer 7 had mean 0.047935398764 and std 0.0720476397823
# hidden layer 8 had mean 0.0348206674628 and std 0.0522436892008
# hidden layer 9 had mean 0.0248145953911 and std 0.0362286147408
# hidden layer 10 had mean 0.0188230611757 and std 0.0270015755462

# %%
D = np.random.randn(1000,500)
hidden_layer_sizes = [500]*10
nonlinearities = ["relu"]*len(hidden_layer_sizes)

act = {"relu" : lambda x:np.maximum(0,x), "tanh" : lambda x:np.tanh(x)}
Hs = {}
for i in xrange(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1]
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) /np.sqrt(fan_in/2)
    
    H = np.dot(X, W)
    H = act[nonlinearities[i]](H)
    Hs[i] = H
    
    print "input layer had mean {} and std {}".format(np.mean(D), np.std(D))
layer_means = [np.mean(H) for i,H in Hs.iteritems()]
layer_stds = [np.std(H) for i,H in Hs.iteritems()]
for i,H in Hs.iteritems():
    print "hidden layer {} had mean {} and std {}".format(i+1, layer_means[i], layer_stds[i])

plt.figure(figsize=(30,10))
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, "ob-")
plt.title("layer mean")
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, "or-")
plt.title('layer std')

plt.figure(figsize=(30,10))
for i,H in Hs.iteritems():
#     if i>1:
#         break
    plt.subplot(1,len(Hs),i+1)
    plt.xlim( 0, 1 )
    plt.hist(H.ravel(), 30 , range=(-1,1))
# Out:
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# input layer had mean -0.000301036263379 and std 0.998902767402
# hidden layer 1 had mean 0.563306986428 and std 0.826750233859
# hidden layer 2 had mean 0.566389398955 and std 0.830191555827
# hidden layer 3 had mean 0.535519997628 and std 0.804265134981
# hidden layer 4 had mean 0.575829335436 and std 0.830903999648
# hidden layer 5 had mean 0.575651780973 and std 0.860093919457
# hidden layer 6 had mean 0.573846961915 and std 0.830472380304
# hidden layer 7 had mean 0.525627289178 and std 0.820483155501
# hidden layer 8 had mean 0.520112359353 and std 0.786422096264
# hidden layer 9 had mean 0.518096947885 and std 0.747036810472
# hidden layer 10 had mean 0.52377181461 and std 0.776892486013
